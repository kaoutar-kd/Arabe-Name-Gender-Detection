# %% [markdown]
# ## Cleaning the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# -*- coding: utf-8 -*-
# coding: utf-8
columns = ["name", "sex"]

# %%
f1 = open(r'/content/train_1.csv',encoding='utf-8',errors = 'backslashreplace' )
f2 = open(r'/content/train_2.csv',encoding='utf-8',errors = 'backslashreplace' )
f3 = open(r'/content/train_3.csv',encoding='ISO-8859-1',errors = 'backslashreplace' )
f1
# Out:
# <_io.TextIOWrapper name='/content/train_1.csv' mode='r' encoding='utf-8'>

# %%
data1 = pd.read_csv(f1 ,header = None ,names = columns)
data2 = pd.read_csv(f2 ,header = None ,names = columns)
data3 = pd.read_csv(f3 ,header = None ,names = columns ,engine='python',quotechar='"', error_bad_lines=False)

# %%
#delete the NaN Values

data1 = data1.dropna().reset_index(drop=True)
data2 = data2.dropna().reset_index(drop=True)
data3 = data3.dropna().reset_index(drop=True)

# %%
# Decoding Names

import re
def replace_e(text):
  text=re.sub('xe1','á',text)
  text=re.sub('xed','í',text)
  text=re.sub('xec','ì',text)
  text=re.sub('xe0','à',text)
  text=re.sub('xc3','Ã',text)
  text=re.sub('xeb','ë',text)
  text=re.sub('xf5','õ',text)
  text=re.sub('xcf','Ï',text)
  text=re.sub('xef','ï',text)
  text=re.sub('xdd','Ý',text)
  text=re.sub('xf3','ó',text)
  text=re.sub('xfa','ú',text)
  text=re.sub('xf8','ø',text)
  text=re.sub('xfc','ü',text)
  text=re.sub('xe2','â',text)
  text=re.sub('xf6','ö',text)
  text=re.sub('xee','î',text)
  text=re.sub('xe9','é',text)
  text=re.sub('xe8','è',text)
  text=re.sub('xe4','ä',text)
  text=re.sub('xc4','Ä',text)
  text=re.sub('xe6','æ',text)
  text=re.sub('xfb','û',text)
  text=re.sub('xce','Î',text)
  text=re.sub('xf1','ñ',text)
  text=re.sub('xc0','À',text)
  text=re.sub('xc1','Á',text)
  text=re.sub('xf4','ô',text)
  text=re.sub('xe3','ã',text)
  text=re.sub('xd8','Ø',text)
  
  return(text)
def remove_d(L):
  for i in range(L.count('\\')):
    L.remove('\\')
for i in range(0,data1.shape[0]):
  print(data1.loc[i,"name"])
  L=list(data1.loc[i,"name"])
  remove_d(L)
  x=''.join(L)
  x=replace_e(x)
  data1.loc[i,"name"] = x
  print(x)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# HòÓú
# HòÓú
# Brahimlkhlil
# Brahimlkhlil
# La\xe7casa
# Laxe7casa
# Yassir
# Yassir
# Mimouch
# Mimouch
# R\xe3j
# Rãj
# adlane
# adlane
# Nesrine Loussaief
# Nesrine Loussaief
# ZAakia
# ZAakia
# Wahdani
# Wahdani
# Khouloud Bouaziz
# Khouloud Bouaziz
# Braiann
# Braiann
# Kalagan
# Kalagan
# Cha\xeem
# Chaîm
# Mimi Mina
# Mimi Mina
# M\xef N\xf8
# Mï Nø
# صديق الزمن الوحيد
# صديق الزمن الوحيد
# حبيب الرحمان
# حبيب الرحمان
# Ervic
# Ervic
# Tlidi
# Tlidi
# \xd1\xf8kr
# xd1økr
# Hadhia
# Hadhia
# Elhacan
# Elhacan
# Jeyarasa
# Jeyarasa
# Sba
# Sba
# Hoël
# Hoël
# M\xf4n
# Môn
# \xc2nw\xe2r
# xc2nwâr
# (*'3E
# (*'3E
# M\xe8h
# Mèh
# Dhahri
# Dhahri
# Ôûmm
# Ôûmm
# Eahmd
# Eahmd
# Prassnms
# Prassnms
# Sillyn
# Sillyn
# H\xe0ss\xf1\xe2
# Hàssñâ
# Rayi Ndirou
# Rayi Ndirou
# Kaeroche
# Kaeroche
# Djambimba
# Djambimba
# M\xe4hd\xef
# Mähdï
# Marrak
# Marrak
# الصمت افضل
# الصمت افضل
# Genjamin
# Genjamin
# ...

# %%
for i in range(0,data2.shape[0]):
  print(data2.loc[i,"name"])
  L=list(data2.loc[i,"name"])
  remove_d(L)
  x=''.join(L)
  x=replace_e(x)
  data2.loc[i,"name"] = x
  print(x)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# ʚĩɞ Čhőű
# ʚĩɞ Čhőű
# Morellet
# Morellet
# Hêř
# Hêř
# Äÿôúb
# Äÿôúb
# Jiditir
# Jiditir
# Sidâ
# Sidâ
# Ouvano
# Ouvano
# جيجل
# جيجل
# Saso Tahfon
# Saso Tahfon
# Že
# Že
# Wajdihileli
# Wajdihileli
# B\xe1dr
# Bádr
#
#
# Quang Tuan
# Quang Tuan
# Lkhmisi
# Lkhmisi
# Cam Phuong
# Cam Phuong
# PiQuinio
# PiQuinio
# Frù
# Frù
# Mounir
# Mounir
# Bakeri
# Bakeri
# Hafizat
# Hafizat
# Sana Sana Janat
# Sana Sana Janat
# Rayen Ben Hassen
# Rayen Ben Hassen
# Leroy Claudin
# Leroy Claudin
# R\xe2j\xe2e
# Râjâe
# Kïno
# Kïno
# يوسف والرقية
# يوسف والرقية
# القضاء
# القضاء
# Lianda
# Lianda
# SareRounte
# SareRounte
# Bëľäřbï
# Bëľäřbï
# HD#FG
# HD#FG
# Polata
# Polata
# Oussama Sabrine
# Oussama Sabrine
# JamiDav
# JamiDav
# Mr\xef\xe5m
# Mrïxe5m
# Nou Nou H
# Nou Nou H
# Sadek Islam
# Sadek Islam
# أ'روي
# أ'روي
# فہٰخامة الہٰسہٰفہٰاحہٰ
# فہٰخامة الہٰسہٰفہٰاحہٰ
# L'áÿan
# L'áÿan
# Axelane
# Axelane
# \xfd
# ...

# %%
for i in range(0,data3.shape[0]):
  print(data3.loc[i,"name"])
  L=list(data3.loc[i,"name"])
  remove_d(L)
  x=''.join(L)
  x=replace_e(x)
  data3.loc[i,"name"] = x
  print(x)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# .'D/ 'DE'-J
# .'D/ 'DE'-J
# BÃ¶ucHrÃ¢
# BÃ¶ucHrÃ¢
# IssÃ m
# IssÃ m
# Jacques-Yves
# Jacques-Yves
# Ä½mÅ¡ofj
# Ä½mÅ¡ofj
# Frawala
# Frawala
# HaJi
# HaJi
# El HÃ£djÃ©
# El HÃ£djÃ©
# MãHã
# MãHã
# PeSo
# PeSo
# Sima Salam
# Sima Salam
# Amel Djouma
# Amel Djouma
# Chymae Al
# Chymae Al
# Biobch
# Biobch
# óþîþ³þÒþ
# óþîþ³þÒþ
# Ø¹Ø²ÙØ±Ù Ø³ÙÙÙ
# Ø¹Ø²ÙØ±Ù Ø³ÙÙÙ
# Àbdôû
# Àbdôû
# KÃ¥b
# KÃ¥b
# IyÃ¦d
# IyÃ¦d
# Inchacti
# Inchacti
# BakkÃªÃ¿
# BakkÃªÃ¿
# ABDERREZEK
# ABDERREZEK
# ÃÅmÃ¡Ã¨
# ÃÅmÃ¡Ã¨
# Youssef Ahmad
# Youssef Ahmad
# Med Zakaria
# Med Zakaria
# Maroufi
# Maroufi
# Linecel
# Linecel
# Greniers Aux
# Greniers Aux
# Samy Younes
# Samy Younes
# Ø¨ÙØªØ¨ÙÙ
# Ø¨ÙØªØ¨ÙÙ
# MÃ¤mÃ¯ttÃ¤
# MÃ¤mÃ¯ttÃ¤
# Àymãnë
# Àymãnë
# ÄÄ«Ä«
# ÄÄ«Ä«
# MarwÃ£ne
# MarwÃ£ne
# Oth
# Oth
# Ãþþßþþ ­þ¿þðþ þßþîþþßþªþóþæþ
# Ãþþßþþ ­þ¿þðþ þßþîþþßþªþóþæþ
# Mastafa
# Mastafa
# ÃtÃ¸Ã®lÄ
# ÃtÃ¸Ã®lÄ
# Yannkee
# ...

# %%
def replace_e(text):
  text=re.sub('xe1','a',text)
  text=re.sub('xed','i',text)
  text=re.sub('xec','i',text)
  text=re.sub('xe0','a',text)
  text=re.sub('xc3','A',text)
  text=re.sub('xeb','e',text)
  text=re.sub('xf5','o',text)
  text=re.sub('xcf','I',text)
  text=re.sub('xef','i',text)
  text=re.sub('xdd','Y',text)
  text=re.sub('xf3','o',text)
  text=re.sub('xfa','u',text)
  text=re.sub('xf8','o',text)
  text=re.sub('xfc','u',text)
  text=re.sub('xe2','a',text)
  text=re.sub('xf6','o',text)
  text=re.sub('xee','i',text)
  text=re.sub('xe9','e',text)
  text=re.sub('xe8','e',text)
  text=re.sub('xe4','e',text)
  text=re.sub('xc4','A',text)
  text=re.sub('xe6','ae',text)
  text=re.sub('xfb','u',text)
  text=re.sub('xce','I',text)
  text=re.sub('xf1','n',text)
  text=re.sub('xc0','A',text)
  text=re.sub('xc1','A',text)
  text=re.sub('xf4','o',text)
  text=re.sub('xe3','a',text)
  text=re.sub('xd8','o',text)
  
  return(text)

for i in range(0,data1.shape[0]):
  print(data1.loc[i,"name"])
  L=list(data1.loc[i,"name"])
  remove_d(L)
  x=''.join(L)
  x=replace_e(x)
  data1.loc[i,"name"] = x
  print(x)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# HòÓú
# HòÓú
# Brahimlkhlil
# Brahimlkhlil
# Laxe7casa
# Laxe7casa
# Yassir
# Yassir
# Mimouch
# Mimouch
# Rãj
# Rãj
# adlane
# adlane
# Nesrine Loussaief
# Nesrine Loussaief
# ZAakia
# ZAakia
# Wahdani
# Wahdani
# Khouloud Bouaziz
# Khouloud Bouaziz
# Braiann
# Braiann
# Kalagan
# Kalagan
# Chaîm
# Chaîm
# Mimi Mina
# Mimi Mina
# Mï Nø
# Mï Nø
# صديق الزمن الوحيد
# صديق الزمن الوحيد
# حبيب الرحمان
# حبيب الرحمان
# Ervic
# Ervic
# Tlidi
# Tlidi
# xd1økr
# xd1økr
# Hadhia
# Hadhia
# Elhacan
# Elhacan
# Jeyarasa
# Jeyarasa
# Sba
# Sba
# Hoël
# Hoël
# Môn
# Môn
# xc2nwâr
# xc2nwâr
# (*'3E
# (*'3E
# Mèh
# Mèh
# Dhahri
# Dhahri
# Ôûmm
# Ôûmm
# Eahmd
# Eahmd
# Prassnms
# Prassnms
# Sillyn
# Sillyn
# Hàssñâ
# Hàssñâ
# Rayi Ndirou
# Rayi Ndirou
# Kaeroche
# Kaeroche
# Djambimba
# Djambimba
# Mähdï
# Mähdï
# Marrak
# Marrak
# الصمت افضل
# الصمت افضل
# Genjamin
# Genjamin
# Hïshàm
# Hïshàm
# Gellier
# Gellier
# ...

# %%
for i in range(0,data2.shape[0]):
  print(data2.loc[i,"name"])
  L=list(data2.loc[i,"name"])
  remove_d(L)
  x=''.join(L)
  x=replace_e(x)
  data2.loc[i,"name"] = x
  print(x)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# ʚĩɞ Čhőű
# ʚĩɞ Čhőű
# Morellet
# Morellet
# Hêř
# Hêř
# Äÿôúb
# Äÿôúb
# Jiditir
# Jiditir
# Sidâ
# Sidâ
# Ouvano
# Ouvano
# جيجل
# جيجل
# Saso Tahfon
# Saso Tahfon
# Že
# Že
# Wajdihileli
# Wajdihileli
# Bádr
# Bádr
#
#
# Quang Tuan
# Quang Tuan
# Lkhmisi
# Lkhmisi
# Cam Phuong
# Cam Phuong
# PiQuinio
# PiQuinio
# Frù
# Frù
# Mounir
# Mounir
# Bakeri
# Bakeri
# Hafizat
# Hafizat
# Sana Sana Janat
# Sana Sana Janat
# Rayen Ben Hassen
# Rayen Ben Hassen
# Leroy Claudin
# Leroy Claudin
# Râjâe
# Râjâe
# Kïno
# Kïno
# يوسف والرقية
# يوسف والرقية
# القضاء
# القضاء
# Lianda
# Lianda
# SareRounte
# SareRounte
# Bëľäřbï
# Bëľäřbï
# HD#FG
# HD#FG
# Polata
# Polata
# Oussama Sabrine
# Oussama Sabrine
# JamiDav
# JamiDav
# Mrïxe5m
# Mrïxe5m
# Nou Nou H
# Nou Nou H
# Sadek Islam
# Sadek Islam
# أ'روي
# أ'روي
# فہٰخامة الہٰسہٰفہٰاحہٰ
# فہٰخامة الہٰسہٰفہٰاحہٰ
# L'áÿan
# L'áÿan
# Axelane
# Axelane
# xfd
# xfd
# Øm
# Øm
# ...

# %%
for i in range(0,data3.shape[0]):
  print(data3.loc[i,"name"])
  L=list(data3.loc[i,"name"])
  remove_d(L)
  x=''.join(L)
  x=replace_e(x)
  data3.loc[i,"name"] = x
  print(x)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# .'D/ 'DE'-J
# .'D/ 'DE'-J
# BÃ¶ucHrÃ¢
# BÃ¶ucHrÃ¢
# IssÃ m
# IssÃ m
# Jacques-Yves
# Jacques-Yves
# Ä½mÅ¡ofj
# Ä½mÅ¡ofj
# Frawala
# Frawala
# HaJi
# HaJi
# El HÃ£djÃ©
# El HÃ£djÃ©
# MãHã
# MãHã
# PeSo
# PeSo
# Sima Salam
# Sima Salam
# Amel Djouma
# Amel Djouma
# Chymae Al
# Chymae Al
# Biobch
# Biobch
# óþîþ³þÒþ
# óþîþ³þÒþ
# Ø¹Ø²ÙØ±Ù Ø³ÙÙÙ
# Ø¹Ø²ÙØ±Ù Ø³ÙÙÙ
# Àbdôû
# Àbdôû
# KÃ¥b
# KÃ¥b
# IyÃ¦d
# IyÃ¦d
# Inchacti
# Inchacti
# BakkÃªÃ¿
# BakkÃªÃ¿
# ABDERREZEK
# ABDERREZEK
# ÃÅmÃ¡Ã¨
# ÃÅmÃ¡Ã¨
# Youssef Ahmad
# Youssef Ahmad
# Med Zakaria
# Med Zakaria
# Maroufi
# Maroufi
# Linecel
# Linecel
# Greniers Aux
# Greniers Aux
# Samy Younes
# Samy Younes
# Ø¨ÙØªØ¨ÙÙ
# Ø¨ÙØªØ¨ÙÙ
# MÃ¤mÃ¯ttÃ¤
# MÃ¤mÃ¯ttÃ¤
# Àymãnë
# Àymãnë
# ÄÄ«Ä«
# ÄÄ«Ä«
# MarwÃ£ne
# MarwÃ£ne
# Oth
# Oth
# Ãþþßþþ ­þ¿þðþ þßþîþþßþªþóþæþ
# Ãþþßþþ ­þ¿þðþ þßþîþþßþªþóþæþ
# Mastafa
# Mastafa
# ÃtÃ¸Ã®lÄ
# ÃtÃ¸Ã®lÄ
# Yannkee
# ...

# %%
#Concatenate the 3 Datasets

data = pd.concat([data1,data2, data3], ignore_index=True)

# %%
#change sex columns to string

data = data.astype({"sex": str}, errors='raise')

# %%
data
# Out:
#                  name     sex
# 0               وفائي  female
# 1              Londra    male
# 2        Salembenanes    male
# 3            KháDíìjà  female
# 4             Mesrouh    male
# ...               ...     ...
# 3884146  Brahim Firas    male
# 3884147  Ø§ÙØ­Ø´Ù
# Ø©  female
# 3884148      HÃ itÃ©m    male
# 3884149         Håmïd    male
# 3884150   Anata Barry    male
#
# [3884151 rows x 2 columns]

# %%
#delete the values from column sex that are not "female" or "male"

data = data[(data['sex'] == 'female' )|( data['sex'] == 'male')]
data.shape
# Out:
# (3736872, 2)

# %%
#reindexing the dataset

data.reset_index(drop=True)
# Out:
#                  name     sex
# 0               وفائي  female
# 1              Londra    male
# 2        Salembenanes    male
# 3            KháDíìjà  female
# 4             Mesrouh    male
# ...               ...     ...
# 3736867  Brahim Firas    male
# 3736868  Ø§ÙØ­Ø´Ù
# Ø©  female
# 3736869      HÃ itÃ©m    male
# 3736870         Håmïd    male
# 3736871   Anata Barry    male
#
# [3736872 rows x 2 columns]

# %%
data.loc[6,"name"]
# Out:
# 'LàîîLàà'

# %%
#delete the non_ascii characteres

s = data['name']

res = s.str.normalize('NFKD')\
       .str.encode('ascii', errors='ignore')\
       .str.decode('utf-8')
res
# Out:
# 0
# 1                Londra
# 2          Salembenanes
# 3              KhaDiija
# 4               Mesrouh
#                ...
# 3884146    Brahim Firas
# 3884147             U U
# 3884148         HA itAm
# 3884149           Hamid
# 3884150     Anata Barry
# Name: name, Length: 3736872, dtype: object

# %%
data['name'] = res
data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                  name     sex
# 0                      female
# 1              Londra    male
# 2        Salembenanes    male
# 3            KhaDiija  female
# 4             Mesrouh    male
# ...               ...     ...
# 3884146  Brahim Firas    male
# 3884147           U U  female
# 3884148       HA itAm    male
# 3884149         Hamid    male
# 3884150   Anata Barry    male
#
# [3736872 rows x 2 columns]

# %%
data['name'] = data['name'].apply(lambda x: ''.join([" " if ord(i) < 32 or ord(i) > 126 else i for i in x]))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#                  name     sex
# 0                      female
# 1              Londra    male
# 2        Salembenanes    male
# 3            KhaDiija  female
# 4             Mesrouh    male
# ...               ...     ...
# 3884146  Brahim Firas    male
# 3884147           U U  female
# 3884148       HA itAm    male
# 3884149         Hamid    male
# 3884150   Anata Barry    male
#
# [3736872 rows x 2 columns]

# %%
print(f'No. of Duplicate titles: {data[data["name"].duplicated() == True].shape[0]}')
# Out:
# No. of Duplicate titles: 1118128

# %%
data[data["name"].duplicated() == True]
# Out:
#           name     sex
# 11                male
# 15                male
# 38                male
# 42                male
# 85              female
# ...        ...     ...
# 3884137     e   female
# 3884142  SA AA  female
# 3884145    Abd    male
# 3884147    U U  female
# 3884149  Hamid    male
#
# [1118128 rows x 2 columns]

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from string import punctuation
from collections import Counter
import operator
import numpy as np
import nltk

# %%
import warnings
warnings.filterwarnings('ignore')  # Let's not pay heed to them right now"

# %%
doc = data['name'].str.replace("[^a-zA-Z#]", " ")
doc
# Out:
# 0
# 1                Londra
# 2          Salembenanes
# 3              KhaDiija
# 4               Mesrouh
#                ...
# 3884146    Brahim Firas
# 3884147             U U
# 3884148         HA itAm
# 3884149           Hamid
# 3884150     Anata Barry
# Name: name, Length: 3736872, dtype: object

# %%
#change characters to lower and delete names with only 1 or 2 or 3 characters

def clean_doc(text):
    text =  ''.join([w.lower() for w in text.split() if len(w)>3])
    return text;

doc = doc.apply(clean_doc)
doc
# Out:
# 0
# 1                londra
# 2          salembenanes
# 3              khadiija
# 4               mesrouh
#                ...
# 3884146     brahimfiras
# 3884147
# 3884148            itam
# 3884149           hamid
# 3884150      anatabarry
# Name: name, Length: 3736872, dtype: object

# %%
data['name']=doc.apply(clean_doc)
data['name'][0]
# Out:
# ''

# %%
data
# Out:
#                  name     sex
# 0                      female
# 1              londra    male
# 2        salembenanes    male
# 3            khadiija  female
# 4             mesrouh    male
# ...               ...     ...
# 3884146   brahimfiras    male
# 3884147                female
# 3884148          itam    male
# 3884149         hamid    male
# 3884150    anatabarry    male
#
# [3736872 rows x 2 columns]

# %%
data.shape
# Out:
# (3736872, 2)

# %%
#data.to_csv("data_clean.csv")

# %% [markdown]
# # Train the model and test it

# %%
f = open(r'/content/data_clean.csv',encoding='utf-8',errors = 'backslashreplace' )
data_clean = pd.read_csv(f ,header = None ,names = columns)
data_clean
# Out:
#                    name     sex
# NaN                name     sex
# 0.0                 NaN  female
# 1.0              londra    male
# 2.0        salembenanes    male
# 3.0            khadiija  female
# ...                 ...     ...
# 3164785.0          rgat  female
# 3164786.0           NaN    male
# 3164787.0        buchra  female
# 3164788.0           NaN    male
# 3164789.0             m     NaN
#
# [3044987 rows x 2 columns]

# %%
data_clean
# Out:
#                    name     sex
# NaN                name     sex
# 0.0                 NaN  female
# 1.0              londra    male
# 2.0        salembenanes    male
# 3.0            khadiija  female
# ...                 ...     ...
# 3164785.0          rgat  female
# 3164786.0           NaN    male
# 3164787.0        buchra  female
# 3164788.0           NaN    male
# 3164789.0             m     NaN
#
# [3044987 rows x 2 columns]

# %%
data_clean = data_clean.replace( '',np.nan, regex=True)
data_clean = data_clean.replace( ' ',np.nan, regex=True)
data_clean = data_clean.replace( '  ',np.nan, regex=True)
data_clean = data_clean.replace( '   ',np.nan, regex=True)

# %%
data_clean = data_clean.dropna().reset_index(drop=True)
data_clean
# Out:
#                    name     sex
# 0                  name     sex
# 1                londra    male
# 2          salembenanes    male
# 3              khadiija  female
# 4               mesrouh    male
# ...                 ...     ...
# 2434327          oshine    male
# 2434328           chaym  female
# 2434329  mustanghakkoum    male
# 2434330            rgat  female
# 2434331          buchra  female
#
# [2434332 rows x 2 columns]

# %%
data_clean = data_clean[(data_clean['sex'] == 'female' )|( data_clean['sex'] == 'male')]
data_clean.dtypes
# Out:
# name    object
# sex     object
# dtype: object

# %%
data_clean.shape
# Out:
# (2434331, 2)

# %%
data_clean
# Out:
#                    name     sex
# 1                londra    male
# 2          salembenanes    male
# 3              khadiija  female
# 4               mesrouh    male
# 5               laiilaa  female
# ...                 ...     ...
# 2434327          oshine    male
# 2434328           chaym  female
# 2434329  mustanghakkoum    male
# 2434330            rgat  female
# 2434331          buchra  female
#
# [2434331 rows x 2 columns]

# %%
# Number of Male Names
data_clean[data_clean.sex == 'male'].size
# Out:
# 3022368

# %%
# Number of Female Names
data_clean[data_clean.sex == 'female'].size
# Out:
# 1846294

# %%
df_names = data_clean
df_names
# Out:
#                    name     sex
# 1                londra    male
# 2          salembenanes    male
# 3              khadiija  female
# 4               mesrouh    male
# 5               laiilaa  female
# ...                 ...     ...
# 2434327          oshine    male
# 2434328           chaym  female
# 2434329  mustanghakkoum    male
# 2434330            rgat  female
# 2434331          buchra  female
#
# [2434331 rows x 2 columns]

# %%
# Replacing All female and male with 0 and 1 respectively
df_names.sex.replace({'female':0,'male':1},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
df_names.sex.unique()
# Out:
# array([1, 0])

# %%
df_names.dtypes
# Out:
# name    object
# sex      int64
# dtype: object

# %%
Xfeatures =df_names['name']

# %%
# ML Packages
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import DictVectorizer
#from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Feature Extraction 
cv = CountVectorizer()
X = cv.fit_transform(Xfeatures)

# %%
cv.get_feature_names()
# Out:
# ['aaaa',
#  'aaaaa',
#  'aaaaaa',
#  'aaaaaaa',
#  'aaaaaaaa',
#  'aaaaaaaaa',
#  'aaaaaaaaaa',
#  'aaaaaaaaaaa',
#  'aaaaaaaaaaaa',
#  'aaaaaaaaaaaaa',
#  'aaaaaaaaaaaaaaa',
#  'aaaaaaaaaaaaaaaa',
#  'aaaaaaaaaaaaaaaaa',
#  'aaaaaaaaaaaaaaaaaaa',
#  'aaaaaaaaaaaaaaaaaaaaaaaaaaa',
#  'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa',
#  'aaaaaaaeao',
#  'aaaaaaao',
#  'aaaaaaat',
#  'aaaaaah',
#  'aaaaaam',
#  'aaaaaao',
#  'aaaaaaoa',
#  'aaaaaaoaa',
#  'aaaaab',
#  'aaaaabaas',
#  'aaaaaca',
#  'aaaaachat',
#  'aaaaad',
#  'aaaaaf',
#  'aaaaafmaamd',
#  'aaaaah',
#  'aaaaai',
#  'aaaaaj',
#  'aaaaak',
#  'aaaaal',
#  'aaaaam',
#  'aaaaama',
#  'aaaaamajad',
#  'aaaaampreaaive',
#  'aaaaan',
#  'aaaaao',
#  'aaaaaoa',
#  'aaaaaoaaa',
#  'aaaaaoe',
#  'aaaaaoeaaaaaodjaoaaaaao',
#  'aaaaaom',
#  'aaaaaorda',
#  'aaaaapaaam',
#  'aaaaar',
#  'aaaaarisao',
#  'aaaaas',
#  'aaaaat',
#  'aaaaau',
#  'aaaaaui',
#  'aaaab',
#  'aaaabawy',
#  'aaaabb',
#  'aaaac',
#  'aaaacha',
#  'aaaachat',
#  'aaaachi',
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
# Features 
X
# Labels
y = df_names.sex

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
X_train
# Out:
# <1631001x1593418 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1631010 stored elements in Compressed Sparse Row format>

# %%
# Naive Bayes Classifier
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.6712347354138399

# %%
# Accuracy of our Model
print("Accuracy of Model",clf.score(X_test,y_test)*100,"%")
# Out:
# Accuracy of Model 67.12347354138399 %

# %%
# Accuracy of our Model
print("Accuracy of Model",clf.score(X_train,y_train)*100,"%")
# Out:
# Accuracy of Model 92.49043992002457 %

# %%
# Sample1 Prediction
sample_name = ["kaoutar"]
vect = cv.transform(sample_name).toarray()

# %%
vect
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]])

# %%
# Female is 0, Male is 1
clf.predict(vect)
# Out:
# array([0])

# %%
# Sample2 Prediction
sample_name1 = ["youssef"]
vect1 = cv.transform(sample_name1).toarray()

# %%
clf.predict(vect1)
# Out:
# array([1])

# %%
# Sample3 Prediction of Russian Names
sample_name2 = ["hafsa"]
vect2 = cv.transform(sample_name2).toarray()

# %%
clf.predict(vect2)
# Out:
# array([0])

# %%
# A function to do it
def genderpredictor(a):
    test_name = [a]
    vector = cv.transform(test_name).toarray()
    if clf.predict(vector) == 0:
        print("Female")
    else:
        print("Male")

# %%
genderpredictor("amine")
# Out:
# Male

# %%
# By Analogy most female names ends in 'A' or 'E' or has the sound of 'A'
def features(name):
    name = name.lower()
    return {
        'first-letter': name[0], # First letter
        'first2-letters': name[0:2], # First 2 letters
        'first3-letters': name[0:4], # First 3 letters
        'last-letter': name[-1],
        'last2-letters': name[-2:],
        'last3-letters': name[-3:],
        'espace_occurance' : str(name.count(' ')),
        'name_len' : str(len(name))
    }

# %%
# Vectorize the features function
features = np.vectorize(features)
print(features(["amina", "noura", "yasmine","youssef","amine","Mohammed"]))
# Out:
# [{'first-letter': 'a', 'first2-letters': 'am', 'first3-letters': 'amin', 'last-letter': 'a', 'last2-letters': 'na', 'last3-letters': 'ina', 'espace_occurance': '0', 'name_len': '5'}
#  {'first-letter': 'n', 'first2-letters': 'no', 'first3-letters': 'nour', 'last-letter': 'a', 'last2-letters': 'ra', 'last3-letters': 'ura', 'espace_occurance': '0', 'name_len': '5'}
#  {'first-letter': 'y', 'first2-letters': 'ya', 'first3-letters': 'yasm', 'last-letter': 'e', 'last2-letters': 'ne', 'last3-letters': 'ine', 'espace_occurance': '0', 'name_len': '7'}
#  {'first-letter': 'y', 'first2-letters': 'yo', 'first3-letters': 'yous', 'last-letter': 'f', 'last2-letters': 'ef', 'last3-letters': 'sef', 'espace_occurance': '0', 'name_len': '7'}
#  {'first-letter': 'a', 'first2-letters': 'am', 'first3-letters': 'amin', 'last-letter': 'e', 'last2-letters': 'ne', 'last3-letters': 'ine', 'espace_occurance': '0', 'name_len': '5'}
# ...

# %%
# Extract the features for the dataset
df_X = features(df_names['name'])

# %%
df_y = df_names['sex']

# %%
from sklearn.feature_extraction import DictVectorizer
 
corpus = features(["amine", "hafsa"])
dv = DictVectorizer()
dv.fit(corpus)
transformed = dv.transform(corpus)
print(transformed)
# Out:
#   (0, 0)	1.0
#   (0, 1)	1.0
#   (0, 3)	1.0
#   (0, 5)	1.0
#   (0, 8)	1.0
#   (0, 9)	1.0
#   (0, 12)	1.0
#   (0, 13)	1.0
#   (1, 0)	1.0
#   (1, 2)	1.0
#   (1, 4)	1.0
#   (1, 6)	1.0
#   (1, 7)	1.0
#   (1, 10)	1.0
#   (1, 11)	1.0
#   (1, 13)	1.0

# %%
dv.get_feature_names()
# Out:
# ['espace_occurance=0',
#  'first-letter=a',
#  'first-letter=h',
#  'first2-letters=am',
#  'first2-letters=ha',
#  'first3-letters=amin',
#  'first3-letters=hafs',
#  'last-letter=a',
#  'last-letter=e',
#  'last2-letters=ne',
#  'last2-letters=sa',
#  'last3-letters=fsa',
#  'last3-letters=ine',
#  'name_len=5']

# %%
df_X
# Out:
# array([{'first-letter': 'l', 'first2-letters': 'lo', 'first3-letters': 'lond', 'last-letter': 'a', 'last2-letters': 'ra', 'last3-letters': 'dra', 'espace_occurance': '0', 'name_len': '6'},
#        {'first-letter': 's', 'first2-letters': 'sa', 'first3-letters': 'sale', 'last-letter': 's', 'last2-letters': 'es', 'last3-letters': 'nes', 'espace_occurance': '0', 'name_len': '12'},
#        {'first-letter': 'k', 'first2-letters': 'kh', 'first3-letters': 'khad', 'last-letter': 'a', 'last2-letters': 'ja', 'last3-letters': 'ija', 'espace_occurance': '0', 'name_len': '8'},
#        ...,
#        {'first-letter': 'm', 'first2-letters': 'mu', 'first3-letters': 'must', 'last-letter': 'm', 'last2-letters': 'um', 'last3-letters': 'oum', 'espace_occurance': '0', 'name_len': '14'},
#        {'first-letter': 'r', 'first2-letters': 'rg', 'first3-letters': 'rgat', 'last-letter': 't', 'last2-letters': 'at', 'last3-letters': 'gat', 'espace_occurance': '0', 'name_len': '4'},
# ...

# %%
# Train Test Split
dfX_train, dfX_test, dfy_train, dfy_test = train_test_split(df_X, df_y, test_size=0.33, random_state=42)

# %%
dv = DictVectorizer()
dv.fit_transform(dfX_train)
# Out:
# <1631001x119747 sparse matrix of type '<class 'numpy.float64'>'
# 	with 13048008 stored elements in Compressed Sparse Row format>

# %%
# Model building Using DecisionTree

from sklearn.tree import DecisionTreeClassifier
 
dclf = DecisionTreeClassifier()
my_xfeatures =dv.transform(dfX_train)
dclf.fit(my_xfeatures, dfy_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
# Build Features and Transform them
sample_name_eg = ["ilyas"]
transform_dv =dv.transform(features(sample_name_eg))

# %%
# Model building Using Naivebayes

clf.fit(my_xfeatures, dfy_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
vect3 = transform_dv.toarray()

# %%
# Predicting Gender of Name
# Male is 1,female = 0
dclf.predict(vect3)
# Out:
# array([1])

# %%
clf.predict(vect3)
# Out:
# array([1])

# %%
if dclf.predict(vect3) == 0:
    print("Female")
else:
    print("Male")
# Out:
# Male

# %%
# Second Prediction With Nigerian Name
name_eg1 = ["malika"]
transform_dv =dv.transform(features(name_eg1))
vect4 = transform_dv.toarray()
if dclf.predict(vect4) == 0:
    print("Female")
else:
    print("Male")
# Out:
# Female

# %%
# A function to do it
def genderpredictor1(a):
    test_name1 = [a]
    transform_dv =dv.transform(features(test_name1))
    vector = transform_dv.toarray()
    if dclf.predict(vector) == 0:
        print("Female")
    else:
        print("Male")

# %%
random_name_list = ["hasna","chaimae","oumaima","abdrahman","karim","taha"]

# %%
for n in random_name_list:
    genderpredictor1(n)
# Out:
# Female
# Female
# Female
# Male
# Male
# Male

# %%
## Accuracy of Models Decision Tree Classifier Works better than Naive Bayes
# Accuracy on training set
print(dclf.score(dv.transform(dfX_train), dfy_train))
# Out:
# 0.9183372665007563

# %%
# Accuracy on test set
print(dclf.score(dv.transform(dfX_test), dfy_test))
# Out:
# 0.6923493458479081

# %%
# Accuracy on test set with Naivebayes
print(clf.score(dv.transform(dfX_test), dfy_test))
# Out:
# 0.7203490470914817

# %%
#DecisionTree

import matplotlib.pyplot as plt  
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(dclf, dv.transform(dfX_test), dfy_test)  
plt.show()

# %%
#NaiveBayes

import matplotlib.pyplot as plt  
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(clf, dv.transform(dfX_test), dfy_test)  
plt.show()

# %% [markdown]
# #### **Saving** Our Model

# %%
from sklearn.externals import joblib
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
decisiontreModel = open("decisiontreemodel.pkl","wb")

# %%
joblib.dump(dclf,decisiontreModel)

# %%
decisiontreModel.close
# Out:
# <function BufferedWriter.close>

# %% [markdown]
# #### Save Multinomial NB Model

# %%
#Alternative to Model Saving
import pickle
dctreeModel = open("namesdetectormodel.pkl","wb")

# %%
pickle.dump(dclf,dctreeModel)

# %%
dctreeModel.close()

# %%
NaiveBayesModel = open("naivebayesgendermodel.pkl","wb")

# %%
joblib.dump(clf,NaiveBayesModel)

# %%
NaiveBayesModel.close()
